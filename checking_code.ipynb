# %%
import pandas as pd
import os
from sqlalchemy import create_engine
engine = create_engine

for file in os.listdir('data'):
    print(file)
# Out:
# begin_inventory.csv
# end_inventory.csv
# purchases.csv
# purchase_prices.csv
# sales.csv
# vendor_invoice.csv
